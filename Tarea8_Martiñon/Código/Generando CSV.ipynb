# %% [markdown]
# # ----- Recolección de datos y generación de CSV ------
# #### Se decidió recolectar primero los datos 'a mano' y convertir a csv para su posterior manejo simplemente a través de una simple lectura

# %% [markdown]
# # Alumno : Martiñón Luna Jonathan José
# # Profesor: Luis Miguel De la Cruz Salas
# # Materia: Visualización de la información
# # Proyecto: Felicidad, ¿Factor importante en el desarrollo de México?
# # Licenciatura en ciencia de datos.

# %% [markdown]
# ### Referencias:
#     - https://datosmacro.expansion.com/indicadores

# %% [markdown]
# ### Vocabulario:
# ### Dataset = Conjunto de datos
# ### Dataframe = Tabla
# ### CSV = Archivo texto extensión .csv representa datos en forma de tablas.
# ### k = *1000,     ej -> 100K = 100,000

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Recolectando datos de México 'A mano'

# %%
# "México índice global de paz"
# Máxima posición ranking 163
# [Fecha, Indice, Ranking Global]
IPG_Mexico = np.array([[2019,2600,140],
                      [2018,2583,140],
                      [2017,2646,142],
                      [2016,2557,140],
                      [2015,2530,144],
                      [2014,2500,138],
                      [2013,2434,133],
                      [2012,2444,134],
                      [2011,2282,118],
                      [2010,2161,100],
                      [2009,2158,98],
                      [2008,2065,88]
                     ])

# %%
# Convertimos a DataFrame 
IPG = pd.DataFrame(data=IPG_Mexico, columns=['Año','Índice','Ranking'])

# Guardamos el DataFrame como archivo csv
IPG.to_csv('./DatosMexico/Indice Global de Paz México.csv', header=True, index=False)

# %%
#Brecha de Género
# Máximo Ranking 149
#[Fecha, Ranking]
Genero_Mexico = np.array([[2018,50,0.7210],
                        [2017,81,0.6920],
                        [2016,66,0.7000],
                        [2015,71,0.6990],
                        [2014,80,0.6900],
                        [2013,68,0.6917],
                        [2012,84,0.6712],
                        [2011,89,0.6604],
                        [2010,91,0.6577],
                        [2009,98,0.6503],
                        [2008,97,0.6441],
                        [2007,93,0.6441],
                        [2006,75,0.6462]
                       ])

# %%
# Convertimos a DataFrame 
Brecha_gen = pd.DataFrame(data=Genero_Mexico,columns=['Año','Ranking','Índice de Brecha de Género'])  

# Guardamos el DataFrame como archivo csv
Brecha_gen.to_csv('./DatosMexico/Brecha de Género México.csv', header=True, index=False)

# %%
# Índice de Desarrollo Humano
#Máximo ranking 189
#[Fecha, IDH, Ranking]
IDH_Mexico = np.array([[2017,0.774,74],
                       [2016,0.722,74],
                       [2015,0.767,145],
                       [2014,0.761,146],
                       [2013,0.756,146],
                       [2012,0.757,143],
                       [2011,0.751,143],
                       [2010,0.743,145],
                       [2009,0.743,141],
                       [2008,0.742,140],
                       [2007,0.739,141],
                       [2006,0.736,137]
                      ])

# %%
# Convertimos a DataFrame 
IDH = pd.DataFrame(data = IDH_Mexico, columns=['Año','IDH','Ranking']) 

# Guardamos el DataFrame como archivo csv
IDH.to_csv('./DatosMexico/Indice de desarrollo humano México.csv', header=True, index=False)

# %%
# Religion en México
# [Fecha, Cristianismo, Judaísmo]
Rel_Mexico = np.array([[2010,96.86,0.06],
                       [2005,93.6,0.12],
                       [2000,96.9,0.12],
                       [1995,97.15,0.07],
                       [1990,96.85,0.13],
                       [1985,97.44,0.1],
                       [1980,96.7,0],
                       [1975,93.36,0.03],
                       [1970,94.7,0.07],
                       [1965,95.66,0.13]
                      ])

# %%
# Convertimos a DataFrame 
Religion = pd.DataFrame(data = Rel_Mexico, columns=['Año','Cristianismo %','Judaísmo %'])

# Guardamos el DataFrame como archivo csv
Religion.to_csv('./DatosMexico/Religion en México.csv', header=True, index=False)

# %%
# Matrimonios en México
#[Fecha, Cant_Matrimonio, Tasa bruta de nupcialidad %]
Mat_Mexico = np.array([[2011,570954,4.9],
                       [2010,568632,5],
                       [2009,558913,5],
                       [2008,589352,5.3],
                       [2007,595209,5.4],
                       [2006,586978,5.4],
                       [2005,595713,5.6],
                       [2004,600563,5.7],
                       [2003,584142,5.6],
                       [2002,616654,6],
                       [2001,665434,6.5],
                       [2000,707422,7]
                      ])

# %%
# Convertimos a DataFrame 
Matrimonios = pd.DataFrame(data=Mat_Mexico, columns=['Año','Matrimonios','Tasa Bruta de Nupcialidad %'])  

# Guardamos el DataFrame como archivo csv
Matrimonios.to_csv('./DatosMexico/Matrimonios en México.csv', header=True, index=False)

# %%
#Reclusos en México
# [ Fecha, Reclusos , por cada 100 K habitantes]
Rec_Mexico = np.array([[2017,181999,140.91],
                       [2016,190175,149.17],
                       [2015,221439,175.90],
                       [2014,228021,183.56],
                       [2013,218373,178.21],
                       [2012,207278,171.55],
                       [2011,213758,179.49],
                       [2010,188013,160.26],
                       [2009,186614,161.56],
                       [2007,214682,191.96],
                       [2006,211308,191.94]
                      ])

# %%
# Convertimos a DataFrame 
Reclusos = pd.DataFrame(data=Rec_Mexico,
                        columns=['Año',
                                 'Reclusos','Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Reclusos.to_csv('./DatosMexico/Reclusos en Mexico.csv', header=True, index=False)

# %%
#Ranking de Felicidad
# Max 156
Fel_Mex = np.array([[2019,23],
                    [2018,24],
                    [2017,25],
                    [2016,21],
                    [2015,14],
                    [2013,16],
                   ])

# %%
# Convertimos a DataFrame 
Felicidad = pd.DataFrame(data=Fel_Mex,columns=['Año','Ranking'])  

# Guardamos el DataFrame como archivo csv
Felicidad.to_csv('./DatosMexico/Ranking de Felicidad Mexico.csv', header=True, index=False)

# %%
# Deuda pública en México
# [Año, Deuda en millones de Euros, Deuda (%PIB)]
Deuda_Mex = np.array([[2018,554636,53.62],
                    [2017,553786,54.05],
                    [2016,552834,56.76],
                    [2015,557352,52.83],
                    [2014,483567,48.88],
                    [2013,440432,45.90],
                    [2012,398645,42.65],
                    [2011,363542,42.86],
                    [2010,334554,41.96],
                    [2009,282142,43.68],
                    [2008,320718,42.49],
                    [2007,285747,37.21],
                    [2006,290695,37.42],
                    [2005,271565,38.52],
                    [2004,256421,40.76],
                    [2003,285219,44.23],
                    [2002,342025,41.86],
                   ])
# Se tenían los datos en Euros, por lo que
# Al recolectarlo se pasaron a pesos (1 e = 25.96 MXN)
Deuda_Mex[:,1] = np.round(Deuda_Mex[:,1]*25.96,2)

# Convertimos a DataFrame 
Deuda = pd.DataFrame(data=Deuda_Mex,columns=['Año','Deuda en Millones de Pesos MXN',' Deuda (%PIB)'])  

# Guardamos el DataFrame como archivo csv
Deuda.to_csv('./DatosMexico/Deuda Mexico.csv', header=True, index=False)

# %%
#Homicidios Intensionados Mexico
# [Año, Número de Homicidios, Víctimas Mujeres, Víctimas Hombres, Homicidios por cada 100,000 Habitantes]
Hom_Mex = np.array([[2017,32079,3444,28635,24.80],
                    [2016,24559,2821,21738,19.30],
                    [2015,20762,2393,18369,16.50],
                    [2014,20010,2420,17590,16.10],
                    [2013,23063,2664,20399,18.80],
                    [2012,25967,2787,23180,21.50],
                    [2011,27213,2719,24494,22.90],
                    [2010,25757,2423,23334,22],
                    [2009,19803,1929,17874,17.10],
                    [2008,14006,1426,12580,12.30],
                    [2007,8867,1084,7783,7.90],
                    [2006,10452,1299,9153,9.5],
                    [2005,9921,1299,8622,9.10],
                    [2004,9329,1207,8122,8.7],
                    [2003,10087,1318,8769,9.5],
                    [2002,10088,1281,8807,9.7],
                    [2001,10285,1284,9001,10],
                    [2000,10737,1285,9452,10.6]
                   ])


# Convertimos a DataFrame 
Hom_Mex = pd.DataFrame(data=Hom_Mex,columns=['Año', 'Homicidios', 'Víctimas Mujeres', 'Víctimas Hombres', 'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Hom_Mex.to_csv('./DatosMexico/Homicidios intencionados México.csv', header=True, index=False)

# %%
# Suicidios en México
# [Año, Total Suicidios, por cada 100 K habitantes]
Suic_Mexico = np.array([[2016,6289,5.20],
                   [2015,6282,5.20],
                   [2014,6215,5.20],
                   [2013,5751,4.90],
                   [2012,5409,4.60],
                   [2011,5602,4.80],
                   [2010,4899,4.30],
                   [2009,5059,4.50],
                   [2008,4668,4.20],
                   [2007,4308,3.90],
                   [2006,4266,3.90],
                   [2005,3571,4.00],
                   [2004,3414,3.90],
                   [2003,3390,3.90],
                   [2002,3189,3.70],
                   [2001,3110,3.70],
                   [2000,2937,3.40],
                   [1999,2830,3.30],
                   [1998,2827,3.40],
                   [1997,2828,3.50],
                   [1996,2523,3.10],
                   [1995,2449,3.10],
                   [1994,2210,2.80]
                  ])


# Convertimos a DataFrame 
Suic_Mexico = pd.DataFrame(data=Suic_Mexico,
                           columns=['Año',
                                    'Suicidios',
                                    'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Suic_Mexico.to_csv('./DatosMexico/Suicidios México.csv',
             header=True, index=False)

# %% [markdown]
# # Recolectando datos 'A mano' de países con alto nivel de Felicidad  para comparar
# ### De acuerdo con 'datosmacro.expansion.com' Finlandia ocupó el primer lugar en el ranking mundial de la felicidad en 2018 y 2019, estando en el Top 5 desde 2016. Por ese motivo se eligió Finlandia.
# ### Noruega se ha mantenido en el Top 5 desde 2013, es por ello que también fue seleccionado como país a comparar.

# %% [markdown]
# ## FINLANDIA

# %%
# Índice mundial de la Felicidad Finlandia
# [AÑO, Posición]
IMF_F = np.array([[2019,1],
                  [2018,1],
                  [2017,5],
                  [2016,5],
                  [2015,6],
                  [2013,7],
                   ])
# Convirtiendo a Dataframe
IMF_F = pd.DataFrame(data=IMF_F,columns=['Año','Ranking']) 

# Almacenando como CSV
IMF_F.to_csv('./Comparaciones/Felicidad/Ranking de Felicidad Finlandia.csv', header=True, index=False)

# %%
# RANKING Índice mundial de la PAZ Finlandia
# [AÑO,índice, Posición]
IMP_F = np.array([[2019,1488,14],
                  [2018,1506,15],
                  [2017,1515,17],
                  [2016,1429,11],
                  [2015,1277,6],
                  [2014,1297,6],
                  [2013,1297,7],
                  [2013,1298,5],
                  [2011,1303,6],
                  [2010,1297,7],
                  [2009,1297,7],
                  [2008,1273,7]
                   ])
# Convirtiendo a Dataframe
IMP_F = pd.DataFrame(data=IMP_F,columns=['Año','Índice','Ranking']) 

# Almacenando como CSV
IMP_F.to_csv('./Comparaciones/Felicidad/Ranking de Paz Finlandia.csv', header=True, index=False)

# %%
# Deuda pública Finlandia
# [AÑO, Deuda en Millones de Euros, Deuda %PIB]
Deuda_F = np.array([[2019,142507,59.40],
                    [2018,138412,59.00],
                    [2017,137391,60.90],
                    [2016,136249,62.60],
                    [2015,133287,63.00],
                    [2014,123778,59.80],
                    [2013,114888,56.20],
                    [2012,107801,53.60],
                    [2011,95576,48.30],
                    [2010,88248,46.90],
                    [2009,75482,41.50],
                    [2008,63254,32.60],
                    [2007,63425,33.90],
                    [2006,65894,38.10],
                    [2005,65759,39.90],
                    [2004,67697,42.60],
                    [2003,64870,42.70],
                    [2002,59661,10.20],
                   ])

# Se tenían los datos de la deuda en Euros, por lo que
# Al recolectarlo se pasaron a pesos (1 e = 25.96 MXN)
Deuda_F[:,1] = np.round(Deuda_F[:,1]*25.96,2)

# Convirtiendo a Dataframe
Deuda_F = pd.DataFrame(data=Deuda_F,
                       columns=['Año',
                                'Deuda en Millones de Pesos MXN',
                                ' Deuda (%PIB)']) 

# Almacenando como CSV
Deuda_F.to_csv('./Comparaciones/Felicidad/Deuda Finlandia.csv', header=True, index=False)

# %%
# Ranking Indice de desarrollo Humano Finlandia
# [AÑO, Ranking]
IDH_F = np.array([[2017,0.920,15],
                  [2016,0.918,15],
                  [2015,0.915,45],
                  [2014,0.914,45],
                  [2013,0.912,42],
                  [2012,0.908,43],
                  [2011,0.907,41],
                  [2010,0.903,44],
                  [2009,0.899,40],
                  [2008,0.904,38],
                  [2007,0.901,39],
                  [2006,0.899,36],
                   ])


# Convirtiendo a Dataframe
IDH_F = pd.DataFrame(data=IDH_F,columns=['Año','IDH','Ranking']) 

# Almacenando como CSV
IDH_F.to_csv('./Comparaciones/Felicidad/Ranking Indice de Desarrollo Humano Finlandia.csv', 
             header=True, index=False)

# %%
# Cantidad de Matrimonios en  Finlandia
# [AÑO, Cantidad, Tasa Bruta de Nupcialidad %]
Mat_F = np.array([[2011,28408,5.3],
                  [2010,29952,5.6],
                  [2009,29836,5.6],
                  [2008,31014,5.8],
                  [2007,29497,5.6],
                  [2006,28236,5.4],
                  [2005,29283,5.6],
                  [2004,29342,5.6],
                  [2003,25815,5],
                  [2002,26969,5.2],
                  [2001,24830,4.8],
                  [2000,26150,5.1],
                   ])


# Convirtiendo a Dataframe
Mat_F = pd.DataFrame(data=Mat_F,columns=['Año','Matrimonios','Tasa Bruta de Nupcialidad %']) 

# Almacenando como CSV
Mat_F.to_csv('./Comparaciones/Felicidad/Matrimonios Finlandia.csv', header=True, index=False)

# %%
#Homicidios Intensionados Finlandia
# [Año, Número de Homicidios, Víctimas Mujeres, Víctimas Hombres, Homicidios por cada 100,000 Habitantes]
Hom_F = np.array([[2017,69,31,38,1.20],
                    [2016,74,22,52,1.30],
                    [2015,82,16,66,1.50],
                    [2014,88,27,61,1.60],
                    [2013,89,24,65,1.60],
                    [2012,88,40,48,1.60],
                    [2011,110,37,73,2],
                    [2010,119,28,91,2.20],
                    [2009,120,34,86,2.20],
                    [2008,133,44,89,2.5],
                    [2007,129,48,81,2.4],
                    [2006,119,37,82,2.3],
                    [2005,119,35,84,2.3],
                    [2004,148,33,115,2.80],
                    [2003,103,30,73,2],
                    [2002,132,44,88,2.5],
                    [2001,156,48,108,3],
                    [2000,148,46,102,2.9]
                   ])


# Convertimos a DataFrame 
Hom_F = pd.DataFrame(data=Hom_F,columns=['Año', 'Homicidios', 'Víctimas Mujeres', 'Víctimas Hombres', 'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Hom_F.to_csv('./Comparaciones/Felicidad/Homicidios Finlandia.csv', header=True, index=False)

# %%
# Religion en Finlandia
# [Año, Cristianismo, Judaísmo, ISLAM]
Rel_F = np.array([[2010,79.40,0.02,0.45],
                  [2005,84.3,0.02,0.45],
                  [2000,86.34,0.02,0.32],
                  [1995,87.02,0.02,0.24],
                  [1990,89.0,0.03,0.16],
                  [1985,89.98,0.03,0.09],
                  [1980,91.38,0.03,0.02],
                  [1975,92.17,0.03,0.02],
                  [1970,93.86,0.03,0.02],
                  [1965,94.40,0.03,0.02]
                ])

# Convertimos a DataFrame 
Rel_F = pd.DataFrame(data=Rel_F,columns=['Año','Cristianismo %','Judaísmo %','Islam %'])  

# Guardamos el DataFrame como archivo csv
Rel_F.to_csv('./Comparaciones/Felicidad/Religion Finlandia.csv', header=True, index=False)

# %%
# Suicidios en Finlandia
# [Año, Total Suicidios, por cada 100 K habitantes]
Suic_F = np.array([[2016,792,14.23],
                   [2015,732,13.34],
                   [2014,797,14.45],
                   [2013,898,16.33],
                   [2012,875,16.12],
                   [2011,910,16.87],
                   [2010,954,17.80],
                   [2009,1034,19.40],
                   [2008,1033,19.40],
                   [2007,995,18.80],
                   [2006,1062,20.20],
                   [2005,994,18.90],
                   [2004,1064,20.40],
                   [2003,1075,20.60],
                   [2002,1095,21.10],
                   [2001,1204,23.20],
                   [2000,1165,22.50],
                   [1999,1207,23.40],
                   [1998,1228,23.80],
                   [1997,1322,25.70],
                   [1996,1247,24.30],
                   [1995,1388,27.20],
                   [1994,1387,27.30]
                  ])


# Convertimos a DataFrame 
Suic_F = pd.DataFrame(data=Suic_F,columns=['Año',
                                         'Suicidios',
                                          'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Suic_F.to_csv('./Comparaciones/Felicidad/Suicidios Finlandia.csv',
             header=True, index=False)

# %%
#Reclusos en Finlandia
# [ Fecha, Reclusos , por cada 100 K Habitantes]
Rec_F = np.array([[2017,3082,55.80],
                  [2016,3156,57.37],
                  [2015,3135,57.19],
                  [2014,3148,57.66],
                  [2013,3295,60.61],
                  [2012,3306,61.08],
                  [2011,3268,60.64],
                  [2010,3364,62.69],
                  [2009,3589,67.18],
                  [2008,3530,66.35],
                  [2007,3625,68.42],
                  [2006,3851,72.97]
                  ])
# Convertimos a DataFrame 
Rec_F = pd.DataFrame(data=Rec_F,columns=['Año',
                                         'Reclusos',
                                          'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Rec_F.to_csv('./Comparaciones/Felicidad/Reclusos Finlandia.csv',
             header=True, index=False)

# %%
# Ranking de Brecha de Género
# Máximo Ranking 149
#[Fecha, Ranking, Índice de Brecha de Género]
Gen_F = np.array([[2018,4,0.8210],
                  [2017,3,0.8230],
                  [2016,2,0.8450],
                  [2015,3,0.8500],
                  [2014,2,0.8453],
                  [2013,2,0.8421],
                  [2012,2,0.8451],
                  [2011,3,0.8383],
                  [2010,3,0.8260],
                  [2009,2,0.8250],
                  [2008,2,0.8195],
                  [2007,3,0.8044],
                  [2006,3,0.7958]
                ])
# Convertimos a DataFrame 
Gen_F = pd.DataFrame(data=Gen_F,columns=['Año',
                                         'Ranking',
                                        'Índice de Brecha de Género'])  

# Guardamos el DataFrame como archivo csv
Gen_F.to_csv('./Comparaciones/Felicidad/Brecha Género Finlandia.csv',
             header=True, index=False)

# %% [markdown]
# ## NORUEGA

# %%
# Índice mundial de la Felicidad Finlandia
# [AÑO, Posición]
IMF_F = np.array([[2019,3],
                  [2018,2],
                  [2017,1],
                  [2016,4],
                  [2015,4],
                  [2013,2],
                   ])
# Convirtiendo a Dataframe
IMF_F = pd.DataFrame(data=IMF_F,columns=['Año','Ranking']) 

# Almacenando como CSV
IMF_F.to_csv('./Comparaciones/Felicidad/Ranking de Felicidad Noruega.csv', header=True, index=False)

# %%
#RANKING Índice mundial de la PAZ NORUEGA
# [AÑO,índice, Posición]
IMP_N = np.array([[2019,1536,20],
                  [2018,1519,16],
                  [2017,1486,14],
                  [2016,1500,17],
                  [2015,1393,17],
                  [2014,1371,10],
                  [2013,1359,11],
                  [2013,1385,14],
                  [2011,1275,4],
                  [2010,1310,8],
                  [2009,1324,8],
                  [2008,1288,9]
                   ])
# Convirtiendo a Dataframe
IMP_N = pd.DataFrame(data=IMP_N,columns=['Año','Índice','Ranking']) 

# Almacenando como CSV
IMP_N.to_csv('./Comparaciones/Felicidad/Ranking de Paz Noruega.csv', header=True, index=False)

# %%
# Deuda pública Noruega
# [AÑO, Deuda en Millones de Euros, Deuda %PIB]
Deuda_N = np.array([[2018,146871,39.97],
                    [2017,430044,36.86],
                    [2016,121387,36.42],
                    [2015,103302,31.60],
                    [2014,95211,27.30],
                    [2013,109235,29.70],
                    [2012,117545,29.10],
                    [2011,98943,27.50],
                    [2010,138311,41.70],
                    [2009,123464,42.80],
                    [2008,126656,48.20],
                    [2007,147084,51.50],
                    [2006,145282,55.40],
                    [2005,104186,44.50],
                    [2004,92430,45.60],
                    [2003,86311,44.30],
                    [2002,69268,36.10],
                   ])


# Se tenían los datos de la deuda en Euros, por lo que
# Al recolectarlo se pasaron a pesos (1 e = 25.96 MXN)
Deuda_N[:,1] = np.round(Deuda_N[:,1]*25.96,2)


# Convirtiendo a Dataframe
Deuda_N = pd.DataFrame(data=Deuda_N,columns=['Año','Deuda en Millones de Pesos MXN',' Deuda (%PIB)']) 

# Almacenando como CSV
Deuda_N.to_csv('./Comparaciones/Felicidad/Deuda Noruega.csv', header=True, index=False)

# %%
# Ranking Indice de desarrollo Humano Noruega
# [AÑO, Ranking]
IDH_N = np.array([[2017,0.953,1],
                  [2016,0.951,1],
                  [2015,0.948,3],
                  [2014,0.946,4],
                  [2013,0.946,3],
                  [2012,0.942,5],
                  [2011,0.943,3],
                  [2010,0.942,3],
                  [2009,0.938,3],
                  [2008,0.938,3],
                  [2007,0.938,2],
                  [2006,0.936,2],
                   ])


# Convirtiendo a Dataframe
IDH_N = pd.DataFrame(data=IDH_N,columns=['Año','IDH','Ranking']) 

# Almacenando como CSV
IDH_N.to_csv('./Comparaciones/Felicidad/Ranking Índice de Desarrollo Humano Noruega.csv',
             header=True, index=False)

# %%
# Cantidad de Matrimonios en  Noruega
# [AÑO, Cantidad, Tasa Bruta de Nupcialidad %]
Mat_N = np.array([[2011,22876,4.6],
                  [2010,23313,4.8],
                  [2009,24299,5],
                  [2008,25125,5.3],
                  [2007,23471,5],
                  [2006,21721,4.7],
                  [2005,22392,4.8],
                  [2004,18655,4.1],
                  [2003,22361,4.9],
                  [2002,20364,4.5],
                  [2001,19722,4.4],
                  [2000,22598,5],
                   ])


# Convirtiendo a Dataframe
Mat_N = pd.DataFrame(data=Mat_N,
                     columns=['Año',
                              'Matrimonios',
                              'Tasa Bruta de Nupcialidad %']) 

# Almacenando como CSV
Mat_N.to_csv('./Comparaciones/Felicidad/Matrimonios Noruega.csv', header=True, index=False)

# %%
#Homicidios Intensionados Noruega
# [Año, Número de Homicidios, Víctimas Mujeres, Víctimas Hombres, Homicidios por cada 100,000 Habitantes]
Hom_N = np.array([[2017,28,13,15,0.50],
                    [2016,27,11,16,0.50],
                    [2015,24,14,10,0.50],
                    [2014,29,13,16,0.60],
                    [2013,46,20,26,0.90],
                    [2012,27,9,18,0.50],
                    [2011,111,52,59,2.20],
                    [2010,29,15,14,0.60],
                    [2009,29,12,17,0.60],
                    [2008,34,10,24,0.7],
                    [2007,30,17,13,0.6],
                    [2006,33,21,12,0.7],
                    [2005,33,16,17,0.7],
                    [2004,36,12,24,0.80],
                    [2003,51,24,27,1.10],
                    [2002,46,15,31,1.0],
                    [2001,37,15,22,0.8],
                    [2000,48,22,26,1.10]
                   ])


# Convertimos a DataFrame 
Hom_N = pd.DataFrame(data=Hom_N,columns=['Año', 'Homicidios', 'Víctimas Mujeres', 'Víctimas Hombres', 'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Hom_N.to_csv('./Comparaciones/Felicidad/Homicidios Noruega.csv', header=True, index=False)

# %%
# Religion en Noruega
# [Año, Cristianismo, Judaísmo, ISLAM]
Rel_N = np.array([[2010,84.01,0.02,2.04],
                  [2005,90.18,0.03,1.66],
                  [2000,88.62,0.03,1.39],
                  [1995,90.91,0.02,0.43],
                  [1990,90.06,0.02,0.33],
                  [1985,89.41,0.02,0.22],
                  [1980,89.47,0.02,0.10],
                  [1975,90.42,0.02,0.10],
                  [1970,92.60,0.02,0.10],
                  [1965,94.52,0.02,0.08]
                ])

# Convertimos a DataFrame 
Rel_N = pd.DataFrame(data=Rel_N,columns=['Año','Cristianismo %','Judaísmo %','Islam %'])  

# Guardamos el DataFrame como archivo csv
Rel_N.to_csv('./Comparaciones/Felicidad/Religion Noruega.csv', header=True, index=False)

# %%
# Suicidios en Noruega
# [Año, Total Suicidios, Suicidios por cada 100,000]
Suic_N = np.array([[2016,627,11.81],
                   [2015,598,11.37],
                   [2014,563,10.65],
                   [2013,566,10.93],
                   [2012,515,10.34],
                   [2011,598,12.13],
                   [2010,548,11.20],
                   [2009,573,11.90],
                   [2008,505,10.60],
                   [2007,485,10.30],
                   [2006,532,11.40],
                   [2005,533,11.50],
                   [2004,529,11.50],
                   [2003,502,11],
                   [2002,494,10.90],
                   [2001,549,12.20],
                   [2000,541,12],
                   [1999,583,13.10],
                   [1998,548,12.40],
                   [1997,533,12.10],
                   [1996,517,11.80],
                   [1995,548,12.60],
                   [1994,531,12.20]
                  ])


# Convertimos a DataFrame 
Suic_N = pd.DataFrame(data=Suic_N,columns=['Año',
                                         'Suicidios',
                                           'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Suic_N.to_csv('./Comparaciones/Felicidad/Suicidios Noruega.csv',
             header=True, index=False)

# %%
#Reclusos en Noruega
# [ Fecha, Reclusos , por cada 100 K Habitantes]
Rec_N = np.array([[2017,3373,63.58],
                  [2016,3850,73.34],
                  [2015,4056,78.00],
                  [2014,4103,79.82],
                  [2013,3869,76.20],
                  [2012,4052,80.85],
                  [2011,3866,78.14],
                  [2010,3564,72.94],
                  [2009,3340,69.19],
                  [2008,3477,72.87],
                  [2007,3446,73.01],
                  [2006,3387,72.48]
                  ])
# Convertimos a DataFrame 
Rec_N = pd.DataFrame(data=Rec_N,columns=['Año',
                                         'Reclusos',
                                          'Por cada 100,000 Habitantes'])  

# Guardamos el DataFrame como archivo csv
Rec_N.to_csv('./Comparaciones/Felicidad/Reclusos Noruega.csv',
             header=True, index=False)

# %%
# Ranking de Brecha de Género
# Máximo Ranking 149
#[Fecha, Ranking, índice de Brecha]
Gen_N = np.array([[2018,2,0.8350],
                  [2017,2,0.8300],
                  [2016,3,0.8420],
                  [2015,2,0.8500],
                  [2014,3,0.8374],
                  [2013,3,0.8417],
                  [2012,3,0.8403],
                  [2011,2,0.8404],
                  [2010,2,0.8404],
                  [2009,3,0.8227],
                  [2008,1,0.8239],
                  [2007,2,0.8059],
                  [2006,2,0.7994]
                ])
# Convertimos a DataFrame 
Gen_N = pd.DataFrame(data=Gen_N,columns=['Año',
                                         'Ranking',
                                        'Índice de Brecha de Género'])  

# Guardamos el DataFrame como archivo csv
Gen_N.to_csv('./Comparaciones/Felicidad/Brecha Género Noruega.csv',
             header=True, index=False)

# %% [markdown]
# # Recolectando datos 'A mano' de países con alto nivel de Desarrollo para comparar
#
# ### En este caso seleccionamos a Suiza, pues de 2013 a 2017 se mantuvo en el Top 10 de países desarrollados, de acuerdo a datosmacro.com
# ### Sólo lo seleccionamos a él, pues los demás tenían cambios bastante bruscos de posiciones

# %%
# Índice mundial de la Felicidad Suiza
# [Año, Ranking]
Fel_S = np.array([[2019,6],
                    [2018,5],
                    [2017,4],
                    [2016,2],
                    [2015,1],
                    [2013,3],
                   ])
# Convertimos a DataFrame 
Fel_S = pd.DataFrame(data=Fel_S,columns=['Año',
                                         'Ranking'])  

# Guardamos el DataFrame como archivo csv
Fel_S.to_csv('./Comparaciones/Desarrollo/Ranking Índice de Felicidad Suiza.csv',
             header=True, index=False)

# %%
# rANKING Índice mundial de la PAZ Suiza
# [AÑO,índice, Posición]
IPG_S = np.array([[2019,1383,11],
                      [2018,1407,12],
                      [2017,1373,9],
                      [2016,1370,7],
                      [2015,1275,5],
                      [2014,1258,5],
                      [2013,1272,5],
                      [2012,1258,4],
                      [2011,1309,8],
                      [2010,1313,9],
                      [2009,1349,11],
                      [2008,1234,4]
                     ]) 
# Convertimos a DataFrame 
IPG_S = pd.DataFrame(data=IPG_S,columns=['Año',
                                         'Índice',
                                         'Ranking'])  

# Guardamos el DataFrame como archivo csv
IPG_S.to_csv('./Comparaciones/Desarrollo/Índice de Paz Suiza.csv',
             header=True, index=False)

# %%
# Deuda pública Suiza
# [Año, Deuda total, Deuda (%PIB)]
Deuda_S = np.array([[2017,256771,42.64],
                    [2016,253370,41.76],
                    [2015,263445,43.01],
                    [2014,229432,42.97],
                    [2013,222547,42.92],
                    [2012,226864,43.67],
                    [2011,215538,42.87],
                    [2010,186985,42.55],
                    [2009,171326,44.07],
                    [2008,172738,45.87],
                    [2007,159308,45.47],
                    [2006,170363,49.62],
                    [2005,184177,56.10],
                    [2004,187274,59.16],
                    [2003,181781,58.21],
                    [2002,188624,59.12],
                   ])

# Se tenían los datos de la deuda en Euros, por lo que
# Al recolectarlo se pasaron a pesos (1 e = 25.96 MXN)
Deuda_S[:,1] = np.round(Deuda_S[:,1]*25.96,2)


# Convirtiendo a Dataframe
Deuda_S = pd.DataFrame(data=Deuda_S,
                       columns=['Año',
                                'Deuda en Millones de Pesos MXN',
                                'Deuda (%PIB)']) 

# Almacenando como CSV
Deuda_S.to_csv('./Comparaciones/Desarrollo/Deuda Suiza.csv', 
               header=True, index=False)

# %%
# Ranking Indice de desarrollo Humano Suiza
#[Año, IDH, Ranking]
IDH_S = np.array([[2017,0.944,2],
                       [2016,0.943,2],
                       [2015,0.942,7],
                       [2014,0.939,9],
                       [2013,0.938,9],
                       [2012,0.935,12],
                       [2011,0.932,14],
                       [2010,0.932,8],
                       [2009,0.927,12],
                       [2008,0.917,19],
                       [2007,0.915,18],
                       [2006,0.912,17]
                      ])
# Convirtiendo a Dataframe
IDH_S = pd.DataFrame(data=IDH_S,
                       columns=['Año',
                                'IDH',
                                'Ranking']) 

# Almacenando como CSV
IDH_S.to_csv('./Comparaciones/Desarrollo/Índice de Desarrollo Suiza.csv', 
               header=True, index=False)

# %%
# Cantidad de Matrimonios en  Suiza
#[Año, Matrimonios, Tasa Bruta de nupcialidad %]
Mat_S = np.array([[2011,42083,5.30],
                  [2010,43257,5.50],
                  [2009,41918,5.40],
                  [2008,41534,5.40],
                  [2007,40330,5.30],
                  [2006,39817,5.30],
                  [2005,40139,5.40],
                  [2004,39460,5.30],
                  [2003,40056,5.50],
                  [2002,40213,5.50],
                  [2001,35987,5.00],
                  [2000,39758,5.50]
                      ])
# Convirtiendo a Dataframe
Mat_S = pd.DataFrame(data=Mat_S,
                       columns=['Año',
                                'Matrimonios',
                                'Tasa Bruta de Nupcialidad %']) 

# Almacenando como CSV
Mat_S.to_csv('./Comparaciones/Desarrollo/Matrimonios Suiza.csv', 
               header=True, index=False)

# %%
# Homicidios Intensionados Suiza
# [Año, Número de Homicidios, Víctimas Mujeres, Víctimas Hombres, Homicidios por cada 100,000 Habitantes]
Hom_S = np.array([[2017,45,20,25,0.50],
                  [2016,45,25,20,0.50],
                  [2015,57,30,27,0.70],
                  [2014,41,24,17,0.50],
                  [2013,57,32,25,0.70],
                  [2012,45,17,28,0.60],
                  [2011,46,23,23,0.60],
                  [2010,52,26,26,0.70],
                  [2009,51,27,24,0.70],
                  [2008,54,25,29,0.70],
                  [2007,51,26,25,0.70],
                  [2006,60,38,22,0.80],
                  [2005,75,38,38,1.00],
                  [2004,78,38,40,1.10],
                  [2003,73,39,34,1.00],
                  [2002,86,49,37,1.20],
                  [2001,86,37,49,1.20],
                  [2000,69,39,30,1.00]
                 ])
# Convirtiendo a Dataframe
Hom_S = pd.DataFrame(data=Hom_S,
                       columns=['Año',
                                'Homicidios',
                                'Víctimas Mujeres',
                               'Víctimas Hombres',
                               'Por cada 100,000 Habitantes']) 

# Almacenando como CSV
Hom_S.to_csv('./Comparaciones/Desarrollo/Homicidios intencionados Suiza.csv', 
               header=True, index=False)

# %%
# Religion en Suiza
#[Año, Cristianismo %, ISLAM %, Judaísmo %]
Rel_S = np.array([[2010,80.56,4.11,0.22],
                       [2005,86.17,4.20,0.24],
                       [2000,82.85,4.21,0.24],
                       [1995,86.52,3.29,0.25],
                       [1990,89.84,2.25,0.26],
                       [1985,93.06,1.61,0.28],
                       [1980,94.63,0.90,0.29],
                       [1975,98.03,0.27,0.34],
                       [1970,98.16,0.27,0.34],
                       [1965,97.85,0.17,0.35]
                      ])
# Convirtiendo a Dataframe
Rel_S = pd.DataFrame(data=Rel_S,
                       columns=['Año',
                                'Cristianismo %',
                                'Islam %',
                                'Judaísmo %']) 

# Almacenando como CSV
Rel_S.to_csv('./Comparaciones/Desarrollo/Religión Suiza.csv', 
               header=True, index=False)

# %%
# Suicidios en Suiza
# [Año, Total Suicidios, por cada 100 K habitantes]
Suic_S = np.array([[2016,1061,12.25],
                   [2015,1101,13.02],
                   [2014,1067,12.77],
                   [2013,1121,13.31],
                   [2012,1079,13.11],
                   [2011,1067,13.16],
                   [2010,1006,12.90],
                   [2009,1105,14.30],
                   [2008,1314,17.20],
                   [2007,1360,18.00],
                   [2006,1309,17.50],
                   [2005,1299,17.50],
                   [2004,1285,17.40],
                   [2003,1269,17.30],
                   [2002,1451,19.90],
                   [2001,1333,18.40],
                   [2000,1380,19.20],
                   [1999,1297,18.20],
                   [1998,1371,19.30],
                   [1997,1341,18.90],
                   [1996,1432,20.20],
                   [1995,1419,20.20],
                   [1994,1494,21.40]
                  ])
# Convirtiendo a Dataframe
Suic_S = pd.DataFrame(data=Suic_S,
                       columns=['Año',
                                'Suicidios',
                                'Por cada 100,000 Habitantes']) 

# Almacenando como CSV
Suic_S.to_csv('./Comparaciones/Desarrollo/Suicidios Suiza.csv', 
               header=True, index=False)

# %%
# Reclusos en Suiza
#[Año, Reclusos, Por cada 100 K Habitantes]
Rec_S = np.array([[2017,6564,77.44],
                       [2016,6541,77.96],
                       [2015,6498,78.10],
                       [2014,6519,79.21],
                       [2013,6652,81.79],
                       [2012,6102,75.97],
                       [2011,5626,70.94],
                       [2010,5765,73.61],
                       [2009,5605,72.44],
                       [2008,5303,69.36],
                       [2007,5278,69.81],
                       [2006,5567,74.41]
                      ])
# Convirtiendo a Dataframe
Rec_S = pd.DataFrame(data=Rec_S,
                       columns=['Año',
                                'Reclusos',
                                'Por cada 100,000 Habitantes']) 

# Almacenando como CSV
Rec_S.to_csv('./Comparaciones/Desarrollo/Reclusos Suiza.csv', 
               header=True, index=False)

# %%
# Ranking de Brecha de Género Suiza
# [ Año, Ranking, índice de Brecha]
Genero_S = np.array([[2018,20,0.7550],
                        [2017,81,0.7550],
                        [2016,11,0.7759],
                        [2015,8,0.7850],
                        [2014,11,0.7798],
                        [2013,9,0.7736],
                        [2012,10,0.7672],
                        [2011,10,0.7627],
                        [2010,10,0.7562],
                        [2009,13,0.7426],
                        [2008,14,0.7360],
                        [2007,40,0.6924],
                        [2006,26,0.6997]
                       ])
# Convirtiendo a Dataframe
Genero_S = pd.DataFrame(data=Genero_S,
                       columns=['Año',
                                'Ranking',
                                'Índice de Brecha de Género']) 

# Almacenando como CSV
Genero_S.to_csv('./Comparaciones/Desarrollo/Brecha de Género Suiza.csv', 
               header=True, index=False)
